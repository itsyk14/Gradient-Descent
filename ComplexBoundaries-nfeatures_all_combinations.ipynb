# %%
from sklearn import datasets

# %%
boston = datasets.load_boston()
X = boston.data
Y = boston.target

# %%
X.shape
# Out:
# (506, 13)

# %%
import pandas as pd
df = pd.DataFrame(X)
df.columns=boston.feature_names
print()

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
for i in range(X.shape[1]):
    new_col_name=boston.feature_names[i]+str('_square')
    df[new_col_name]=df.iloc[:,i]**2
print(df)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  ...  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0  ...
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0  ...
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0  ...
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0  ...
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0  ...
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0  ...
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0  ...
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0  ...
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0  ...
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0  ...
#
# ...

# %%
df.columns[12]
# Out:
# 'LSTAT'

# %%
df.columns[13]
# Out:
# 'CRIM_square'

# %%
df.columns[25]
# Out:
# 'LSTAT_square'

# %%
df.columns[26]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-23f2923c61f1> in <module>
# ----> 1 df.columns[26]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3928         if is_scalar(key):
#    3929             key = com.cast_scalar_indexer(key)
# -> 3930             return getitem(key)
#    3931
#    3932         if isinstance(key, slice):
#
# IndexError: index 26 is out of bounds for axis 0 with size 26

# %%
for i in range(13,26):
    for j in range(i+1,26):
        new_col_name=df.columns[i]+"--"+df.columns[j]
        df[new_col_name]=df.iloc[:,i]*df.iloc[:,j]

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  ...  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0  ...
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0  ...
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0  ...
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0  ...
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0  ...
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0  ...
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0  ...
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0  ...
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0  ...
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0  ...
#
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# CRIM
# ZN
# INDUS
# CHAS
# NOX
# RM
# AGE
# DIS
# RAD
# TAX
# PTRATIO
# B
# LSTAT
# CRIM_square
# ZN_square
# INDUS_square
# CHAS_square
# NOX_square
# RM_square
# AGE_square
# DIS_square
# RAD_square
# TAX_square
# PTRATIO_square
# B_square
# LSTAT_square
# CRIM_square--ZN_square
# CRIM_square--INDUS_square
# CRIM_square--CHAS_square
# CRIM_square--NOX_square
# CRIM_square--RM_square
# CRIM_square--AGE_square
# CRIM_square--DIS_square
# CRIM_square--RAD_square
# CRIM_square--TAX_square
# CRIM_square--PTRATIO_square
# CRIM_square--B_square
# CRIM_square--LSTAT_square
# ZN_square--INDUS_square
# ZN_square--CHAS_square
# ZN_square--NOX_square
# ZN_square--RM_square
# ZN_square--AGE_square
# ZN_square--DIS_square
# ZN_square--RAD_square
# ZN_square--TAX_square
# ZN_square--PTRATIO_square
# ZN_square--B_square
# ZN_square--LSTAT_square
# INDUS_square--CHAS_square
# INDUS_square--NOX_square
# INDUS_square--RM_square
# INDUS_square--AGE_square
# INDUS_square--DIS_square
# ...

# %%
X2=df.values

# %%
X2.shape
# Out:
# (506, 104)

# %%
X.shape
# Out:
# (506, 13)

# %%
from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, random_state = 0)
X2_train, X2_test, Y2_train, Y2_test = model_selection.train_test_split(X2, Y, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
alg1 = LinearRegression()
alg2 = LinearRegression()

# %%
alg1.fit(X_train, Y_train)
alg2.fit(X2_train, Y2_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred = alg1.predict(X_test)
train_score = alg1.score(X_train, Y_train)
test_score = alg1.score(X_test, Y_test)
print("Train Score: ", train_score)
print("Test Score: ", test_score)

train2_score = alg2.score(X2_train, Y2_train)
test2_score = alg2.score(X2_test, Y2_test)
print("Train2 Score: ", train2_score)
print("Test2 Score: ", test2_score)
# Out:
# Train Score:  0.7697699488741149
# Test Score:  0.6354638433202129
# Train2 Score:  0.9420169891451338
# Test2 Score:  0.7026180616668884
